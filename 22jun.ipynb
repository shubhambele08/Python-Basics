# %%
a={1,2,4,6,3,2,6}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a|b
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a&b
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a-b
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.intersection(b)
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.difference(b)
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 7}

# %%
dct={1:"ABC"}
print(dct)
# Out:
# {1: 'ABC'}

# %%
for i in dct.keys():
  print(i)
# Out:
# 1

# %%
for i in dct.values():
  print(i)
# Out:
# ABC

# %%
for i,j in dct.items():
  print(i,j)
# Out:
# 1 ABC

# %%
dct={1:"ABC",2:"PQR",3:"XYZ",4:"ACB",5:"ZYX"}
for key,values in dct.items():
  print(f"roll no",key,"Name:",values)
# Out:
# roll no 1 Name: ABC
# roll no 2 Name: PQR
# roll no 3 Name: XYZ
# roll no 4 Name: ACB
# roll no 5 Name: ZYX

# %%
dct[3]="CBX"
print(dct)
# Out:
# {1: 'ABC', 2: 'PQR', 3: 'CBX', 4: 'ACB', 5: 'ZYX', 6: 'ABC'}

# %%
dct[6]="ABC"
print(dct)
# Out:
# {1: 'ABC', 2: 'PQR', 3: 'XYZ', 4: 'ACB', 5: 'ZYX', 6: 'ABC'}

# %%
dct.get(3)
# Out:
# 'CBX'

# %%
dct.get(10,"Not Found")
# Out:
# 'Not Found'

# %%
sample={"days":["mon","Tue","Wed","Thu"],
        "Planets":["Sun","Saturn","Earth"]}
for key,values in sample.items():
  print(values)
# Out:
# ['mon', 'Tue', 'Wed', 'Thu']
# ['Sun', 'Saturn', 'Earth']

# %%
sample={1:1,2:2,3:3}
for key,values in sample.items():
  print(key,values)
# Out:
# 1 1
# 2 2
# 3 3

# %%
sample={1:1,2:1,3:1}
for key,values in sample.items():
  print(key,values)
# Out:
# 1 1
# 2 1
# 3 1

# %%
sample={(1,2):1}
for key,values in sample.items():
  print(key,values)
# Out:
# (1, 2) 1

# %%
n=int(input())
for row in range(n,0,2):
  for col in range(row+1,n,-1):
    print("*",end=" ")
  print()
# Out:
# 3

# %%
  *
 **
***

# %%
n=int(input())
for i in range(n,0,-1):
  for j in range(i,0,-1):
    print("*",end=" ")
  print()

# %%
n=int(input())
for row in range(n):
  for col in range(n):
    ele=max(row+1,col+1,n-row,n-col)
    print(ele,end=" ")
  print()
# Out:
# 5
# 5 5 5 5 5
# 5 4 4 4 5
# 5 4 3 4 5
# 5 4 4 4 5
# 5 5 5 5 5
